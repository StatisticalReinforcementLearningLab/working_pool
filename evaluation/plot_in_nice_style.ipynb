# %%
import numpy as np
import pickle
import os
import math
import matplotlib.pyplot as plt
import math
import numpy as np
import sys
sys.path
from scipy import stats
sys.path.append('../simulation')
import TS_personal_params_pooled as pp
import TS_global_params_pooled as gtp
# %matplotlib inline

# %%
##metrics 
#look at reduction in error in first week, difference in regret from first decision to 5*7th decision
#35- 0th decision time
##look at regret in the first 100 decision times
plt.rc('text', usetex=True)
#plt.rc('font', family='serif')

# %%
def get_results(results_path,pop_size,update_time,case,phrase,ophrase):
    
    
    files = os.listdir('{}{}'.format(results_path,case))
    
    steps = []

    #check population and pop_size,update_time
    files = [f for f in files if '.DS' not in f and pop_size in f and phrase in f and ophrase not in f and 'update_days_{}'.format(update_time) in f  and '2015' not in f    ]
    #files = files[:50]
    #print(len(files))
    #print(files)
    seen = 0 
    regrets = {}
    actions = {}
    mus = {}
    for ff in files:
        #sim = int(ff.split('sim_')[1].strip('_continuous_pretreatment_base_coef_scale_hybrid.pkl'))
        #try:
        with open('{}{}/{}'.format(results_path,case,ff),'rb') as f:
            d = pickle.load(f)
            #return d
            #print(d.keys())
            if len(d)>0:
            #if int(sim)<60:
                #print(len([k['steps'] for k in d['history'].values() if k['avail'] and k['decision_time']]))
                steps = steps+[k['steps'] for k in d['history'].values() if k['avail'] and k['decision_time']]
                for k,v in d['actions'].items():
                    if k not in actions:
                        actions[k]=[]
                    actions[k].extend(v)
                for k,v in d['regrets'].items():
                    if k not in regrets:
                        regrets[k]=[]
                    regrets[k].extend(v)
            seen = seen+1
           # print(ff)
    print(seen)
    return {'steps':steps,'regrets':regrets,'actions':actions}

# %%
def get_to_plot_actions(actions):
    
    skeys = sorted(actions.keys())
    to_plot = []
    for k in skeys:
        to_plot.append(sum(actions[k])/len(actions[k]))
    return to_plot
def get_to_plot_regrets(actions):
    
    skeys = sorted(actions.keys())
    to_plot = []
    for k in skeys:
        to_plot.append(np.array(actions[k]).mean())
    return to_plot

# %%
def get_decision_times(d,title,save_title,save=False,i=None,ax=None):
    
    x =get_to_plot_actions(d['actions'])
   
    to_plotr =  get_to_plot_regrets(d['regrets'])
    return x,to_plotr,[]

# %%
def get_decision_times_sims(d,title,save_title,save=False,i=None,ax=None):
    actions = {}
    regrets ={}
    steps = []
    for sim,sims in d['actions'].items():
        for k,v in sims.items():
            if k not in actions:
                actions[k]=[]
            actions[k].extend(v)
    for sim,sims in d['regrets'].items():
        for k,v in sims.items():
            if k not in regrets:
                regrets[k]=[]
            regrets[k].extend(v)
   # for sim,sims in d['steps'].items():
        
           
             
        #steps[k].extend(sims)
 
    return get_to_plot_actions(actions),get_to_plot_regrets(regrets),steps
#,get_to_plot_regrets(steps)

# %%
def get_all(results_path,pop,update,phrase,ophrase):
    to_return = {}
    cases = ['case_one','case_two','case_three']
   
    for i in range(len(cases)):
        case = cases[i]
        d = get_results(results_path,str(pop),update,cases[i],phrase,ophrase)
        
        act,regret,steps = get_decision_times(d,case,case,save=False,i=i,ax=None)
        to_return[case]={'actions':act,'regrets':regret,'steps':steps}
    return to_return

# %%
def get_all_d(dic):
    to_return = {}
    cases = ['case_one','case_two','case_three']
   
    for i in range(len(cases)):
        case = cases[i]
        d = dic[case]
        act,regret,steps  = get_decision_times_sims(d,case,case,save=False,i=i,ax=None)
        to_return[case]={'actions':act,'regrets':regret,'steps':steps}
    return to_return

# %%
with open('../../Downloads/pooling_four_results_7_24_p_0.pkl','rb') as f:
    pooled = pickle.load(f)

# %%
with open('../../Downloads/hob_clipped_degree_one.pkl','rb') as f:
    three = pickle.load(f)

# %%
h = get_all_d(three)

# %%
def get_weekly_averages(points):
    to_return = []
    sems = []
    for i in range(0,len(points)-5,35):
        temp = points[i:i+35]
        to_return.append(np.array(temp).mean())
        #print(temp)
        sems.append(stats.sem(temp))
    return to_return,sems

# %%
def get_daily_averages(points):
    to_return = []
    sems = []
    for i in range(0,len(points)-5,5):
        temp = points[i:i+5]
        to_return.append(np.array(temp).mean())
        #print(temp)
        sems.append(stats.sem(temp))
    return to_return,sems

# %%
#pooled['case_one'][1].keys()

# %%
t= get_all_d(pooled)

# %%
def plot_all_special_actions(batch,personalized,pooled):
    
    fig, ax = plt.subplots(nrows=1, ncols=3)
    fig.tight_layout( w_pad=2.5, h_pad=1.0)

    #'case_one','case_two',
    cases = ['case_one','case_two','case_three']
    plt.setp(ax[:],  yticks = np.arange(.4, .85, step=0.10),ylim = [.4,.85])
    #plt.setp(ax[1,:],  yticks = np.arange(0, .5, step=0.05),ylim = [0,.5])
    #'Homogenous','Bi-modal',
    
    titles = ['Homogenous','Bi-modal','Smooth']
    offset = 5
    for i in range(len(cases)):
            if i==0:
                #plt.setp(ax[0],  yticks = np.arange(0, .15, step=0.05),ylim = [0,.15])
                ax[i].set_ylabel("Average Weekly Percent Correct Action " r"$\rho^*$")
                #("Average Weekly Percent Correct Action r"$\rho$!"")
            if i==1:
                
                #plt.setp(ax[1],  yticks = np.arange(0, .3, step=0.05),ylim = [0,.3])
                ax[i].set_xlabel('Week of study')
            #if i==2:
                #plt.setp(ax[2],  yticks = np.arange(0, .3, step=0.05),ylim = [0,.3])
            ax[i].set_title(titles[i])
            
            b =get_weekly_averages(batch[cases[i]]['actions'])
            #labels = ['{}'.format(i) for i in range(0,len(b),15) ]
            #print([i for i in range(len(b[0]))])
            ax[i].errorbar([i for i in range(len(b[0]))],b[0],yerr=b[1],fmt='o-',label='Complete')
            
            #print(len([b[j] for j in range(0,len(b),25)]))
          
            p =get_weekly_averages(personalized[cases[i]]['actions'])
            ax[i].errorbar([i for i in range(len(p[0]))],p[0],yerr=p[1],fmt='+-',label='Person-specific')
         
            po =get_weekly_averages(pooled[cases[i]]['actions'])
            ax[i].errorbar([i for i in range(len(po[0]))],po[0],yerr=po[1],label='IntelligentPooling')
            #xx=[i for i in range(int(len([b[j] for j in range(0,len(b),offset)])/4),len([b[j] for j in range(0,len(b),offset)]),int(len([b[j] for j in range(0,len(b),offset)])/4))]
            #print(xx)
            #print([j for j in range(0,len(b),offset)])
            xx = [i for i in range(0,12*7,2)]
            labels = ['{}'.format(i) for i in range(0,12*7,2) ]
            #labels = ['{}'.format(i*offset) for i in xx ]
            
            #print(labels)
            #print(xx)
            #print(len(labels))
            #print(len(xx))
            ax[i].set_xticks(xx)
            ax[i].set_xticklabels(labels)
    plt.legend(bbox_to_anchor=(1.15, .5)) 
    #plt.savefig('all_12weeks_rho',dpi=300, bbox_inches='tight')

# %%
def plot_all_special_actions_ne(batch,personalized,pooled,hob,hobwrong,pn):
    
    fig, ax = plt.subplots(nrows=1, ncols=3)
    fig.tight_layout( w_pad=2.5, h_pad=1.0)

    #'case_one','case_two',
    cases = ['case_one','case_two','case_three']
    plt.setp(ax[:],  yticks = np.arange(.4, .85, step=0.10),ylim = [.4,.85])
    #plt.setp(ax[1,:],  yticks = np.arange(0, .5, step=0.05),ylim = [0,.5])
    #'Homogenous','Bi-modal',
    
    titles = ['Homogenous','Bi-modal','Smooth']
    offset = 5
    for i in range(len(cases)):
            if i==0:
                #plt.setp(ax[0],  yticks = np.arange(0, .15, step=0.05),ylim = [0,.15])
                ax[i].set_ylabel("Average Weekly Percent Correct Action " r"$\rho^*$")
                #("Average Weekly Percent Correct Action r"$\rho$!"")
            if i==1:
                
                #plt.setp(ax[1],  yticks = np.arange(0, .3, step=0.05),ylim = [0,.3])
                ax[i].set_xlabel('Week of study')
            #if i==2:
                #plt.setp(ax[2],  yticks = np.arange(0, .3, step=0.05),ylim = [0,.3])
            ax[i].set_title(titles[i])
            
            b =get_weekly_averages(batch[cases[i]]['actions'])
            #labels = ['{}'.format(i) for i in range(0,len(b),15) ]
            #print([i for i in range(len(b[0]))])
            ax[i].plot(b[0],'o-',label='Complete-pooling')
            
            #print(len([b[j] for j in range(0,len(b),25)]))
          
            p =get_weekly_averages(personalized[cases[i]]['actions'])
            ax[i].plot(p[0],'+-',label='Person-specific')
         
            po =get_weekly_averages(pooled[cases[i]]['actions'])
            ax[i].plot(po[0],label='IntelligentPooling')
            
                        
            h =get_weekly_averages(hob[cases[i]]['actions'])
            #print(po)
            #yerr=po[1],
            ax[i].plot(h[0],label='HOB-Correct')
            
            h =get_weekly_averages(hobwrong[cases[i]]['actions'])
            #print(po)
            #yerr=po[1],
            ax[i].plot(h[0],label='HOB-Incorrect')
            
            #ax[i].axvline(x=8)
            #xx=[i for i in range(int(len([b[j] for j in range(0,len(b),offset)])/4),len([b[j] for j in range(0,len(b),offset)]),int(len([b[j] for j in range(0,len(b),offset)])/4))]
            #print(xx)
            #print([j for j in range(0,len(b),offset)])
            xx = [i for i in range(0,12,2)]
            labels = ['{}'.format(i) for i in range(0,12,2) ]
            #labels = ['{}'.format(i*offset) for i in xx ]
            
            #print(labels)
            #print(xx)
            #print(len(labels))
            #print(len(xx))
            ax[i].set_xticks(xx)
            ax[i].set_xticklabels(labels)
    plt.legend(bbox_to_anchor=(1.15, .5)) 
    plt.savefig('temp_plots/percent_correct_trial_number_{}.pdf'.format(pn),dpi=1200, bbox_inches='tight')

# %%
def plot_all_special_actions_first_week(batch,personalized,pooled,hob,k):
    
    fig, ax = plt.subplots(nrows=1, ncols=3)
    fig.tight_layout( w_pad=2.5, h_pad=1.0)

    #'case_one','case_two',
    cases = ['case_one','case_two','case_three']
    plt.setp(ax[:],  yticks = np.arange(.4, .85, step=0.10),ylim = [.4,.85])
    #plt.setp(ax[1,:],  yticks = np.arange(0, .5, step=0.05),ylim = [0,.5])
    #'Homogenous','Bi-modal',
    
    titles = ['Homogenous','Bi-modal','Smooth']
    offset = 5
    for i in range(len(cases)):
            if i==0:
                #plt.setp(ax[0],  yticks = np.arange(0, .15, step=0.05),ylim = [0,.15])
                ax[i].set_ylabel("Average Weekly Percent Correct Action " r"$\rho^*$")
                #("Average Weekly Percent Correct Action r"$\rho$!"")
            if i==1:
                
                #plt.setp(ax[1],  yticks = np.arange(0, .3, step=0.05),ylim = [0,.3])
                ax[i].set_xlabel('Week of study')
            #if i==2:
                #plt.setp(ax[2],  yticks = np.arange(0, .3, step=0.05),ylim = [0,.3])
            ax[i].set_title(titles[i])
            
            b =get_daily_averages(batch[cases[i]]['actions'])
            #labels = ['{}'.format(i) for i in range(0,len(b),15) ]
            #print([i for i in range(len(b[0]))])
            ax[i].plot(b[0][:k],'o-',label='Complete-pooling')
            
            #print(len([b[j] for j in range(0,len(b),25)]))
          
            p =get_daily_averages(personalized[cases[i]]['actions'])
            ax[i].plot(p[0][:k],'+-',label='Person-specific')
         
            po =get_daily_averages(pooled[cases[i]]['actions'])
            ax[i].plot(po[0][:k],label='IntelligentPooling')
            
            h =get_weekly_averages(hob[cases[i]]['actions'])
            #print(po)
            #yerr=po[1],
            ax[i].plot(h[0],label='HOB')
            
            #xx=[i for i in range(int(len([b[j] for j in range(0,len(b),offset)])/4),len([b[j] for j in range(0,len(b),offset)]),int(len([b[j] for j in range(0,len(b),offset)])/4))]
            #print(xx)
            #print([j for j in range(0,len(b),offset)])
            xx = [i for i in range(0,k,5)]
            labels = ['{}'.format(i) for i in range(0,k,5) ]
            #labels = ['{}'.format(i*offset) for i in xx ]
            
            #print(labels)
            #print(xx)
            #print(len(labels))
            #print(len(xx))
            ax[i].set_xticks(xx)
            ax[i].set_xticklabels(labels)
    plt.legend(bbox_to_anchor=(1.15, .5)) 
    #plt.savefig('all_12weeks_65.pdf',dpi=1200, bbox_inches='tight')

# %%
def plot_all_special_regret(batch,personalized,pooled,hob,hobwrong,pn):
    
    fig, ax = plt.subplots(nrows=1, ncols=3)
    fig.tight_layout( w_pad=2.5, h_pad=1.0)

    #'case_one','case_two',
    cases = ['case_one','case_two','case_three']
    plt.setp(ax[:],  yticks = np.arange(.4, .85, step=0.10),ylim = [.4,.85])
    #plt.setp(ax[1,:],  yticks = np.arange(0, .5, step=0.05),ylim = [0,.5])
    #'Homogenous','Bi-modal',
    
    titles = ['Homogenous','Bi-modal','Smooth']
    offset = 5
    for i in range(len(cases)):
            if i==0:
                plt.setp(ax[0],  yticks = np.arange(0.00, .17, step=0.05),ylim = [0.00,.17])
                ax[i].set_ylabel('Average weekly regret')
            if i==1:
                
                plt.setp(ax[1],  yticks = np.arange(0.00, .17, step=0.05),ylim = [0.00,.17])
                ax[i].set_xlabel('Decision times')
            if i==2:
                plt.setp(ax[2],  yticks = np.arange(0.05, .25, step=0.05),ylim = [0.05,.25])
            ax[i].set_title(titles[i])
            
            b =get_weekly_averages(batch[cases[i]]['regrets'])
            #print(b)
            #labels = ['{}'.format(i) for i in range(0,len(b),15) ]
            #yerr=b[1],
            #[i for i in range(len(b[0]))],
            ax[i].plot(b[0],'o-',label='Complete-pooling')
            
            #print(len([b[j] for j in range(0,len(b),25)]))
          
            p =get_weekly_averages(personalized[cases[i]]['regrets'])
            #yerr=p[1],
            #[i for i in range(len(p[0]))]
            ax[i].plot(p[0],'+-',label='Person-specific')
         
            po =get_weekly_averages(pooled[cases[i]]['regrets'])
            #print(po)
            #yerr=po[1],
            ax[i].plot(po[0],label='IntelligentPooling')
            
            
            h =get_weekly_averages(hob[cases[i]]['regrets'])
            #print(po)
            #yerr=po[1],
            ax[i].plot(h[0],label='HOB-Correct')
            
            
            h =get_weekly_averages(hobwrong[cases[i]]['regrets'])
            #print(po)
            #yerr=po[1],
            ax[i].plot(h[0],label='HOB-Incorrect')
            
            #xx=[i for i in range(int(len([b[j] for j in range(0,len(b),offset)])/4),len([b[j] for j in range(0,len(b),offset)]),int(len([b[j] for j in range(0,len(b),offset)])/4))]
            #print(xx)
            #print([j for j in range(0,len(b),offset)])
            xx = [i for i in range(0,14,2)]
            labels = ['{}'.format(i) for i in range(0,14,2) ]
            #labels = ['{}'.format(i*offset) for i in xx ]
            
            #print(labels)
            #print(xx)
            #print(len(labels))
            #print(len(xx))
            ax[i].set_xticks(xx)
            ax[i].set_xticklabels(labels)
    plt.legend(bbox_to_anchor=(1.15, .5)) 
    plt.savefig('temp_plots/regret_trial_number_{}.pdf'.format(pn),dpi=300, bbox_inches='tight',)

# %%
def plot_all_one_pn(pn):
    with open('../../Downloads/pooling_four_results_7_24_pn_{}.pkl'.format(pn),'rb') as f:
        pooled = pickle.load(f)      
    t= get_all_d(pooled)
    fb = get_all('../../Downloads/pooling_results_testing/batch/','32',7,'pop_{}'.format(pn),'coef')
    fp = get_all('../../Downloads/pooling_results_testing/personalized/','32',7,'pop_{}'.format(pn),'coef')
    fh = get_all('../../Downloads/pooling_results_testing/hob_clipped/','32',7,'pop_{}_testing_newrandom_incorrect'.format(pn),'coef')
    fc = get_all('../../Downloads/pooling_results_testing/hob_clipped/','32',7,'pop_{}_testing_newrandom_correct'.format(pn),'coef')
    plot_all_special_actions_ne(fb,fp,t,fc,fh,pn)
    plot_all_special_regret(fb,fp,t,fc,fh,pn)

# %%
for i in range(10):
    plot_all_one_pn(i)
# Out:
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50
# 50

# %%
fb = get_all('../../Downloads/pooling_results/batch/','32',1,'location_7_19','coef')
# Out:
# 50
# 50
# 50

# %%
fp = get_all('../../Downloads/pooling_results/personalized/','32',1,'location_7_19','coef')
# Out:
# 50
# 50
# 50

# %%
fh = get_all('../../Downloads/pooling_results_testing/hob_clipped/','32',7,'testing_newrandom','coef')
# Out:
# 50
# 50
# 50

# %%
#varrc02

# %%
fc = get_all('../../Downloads/pooling_results_testing/hob_clipped/','32',7,'pop_0_testing_newrandom_correct','coef')
# Out:
# 0
# 0
# 50

# %%
fp = get_all('../../Downloads/pooling_results_testing/personalized/','32',7,'testing_newwriting','coef')

# %%
plt.rcParams.update({'font.size': 16})

# %%
plot_all_special_actions_ne(fb,fp,t,fc,fh)

# %%
plot_all_special_actions_ne(fb,fp,t,fh)

# %%
plot_all_special_actions_ne(fb,fp,t,fh)

# %%
plot_all_special_actions_ne(fb,fp,t,fh)

# %%
plot_all_special_actions_ne(fb,fp,t,fh)

# %%
plot_all_special_regret(fb,fp,t,fc,fh)

# %%
plot_all_special_regret(fb,fp,t,fc,fh)

# %%
50*5*7*12
# Out:
# 21000

# %%
plt.errorbar(x=[i for i in range(len(wfb[0]))],y=wfb[0],yerr=wfb[1],fmt='o-',label='Complete')
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
case = 'case_two'

# %%
wfb = get_weekly_averages(fb[case]['actions'])
#wf = get_weekly_averages(fp[case])
#wp = get_weekly_averages(t[case])
# Out:
# [0.4683346364347146, 0.48985959438377535, 0.508209538702111, 0.5059288537549407, 0.5003897116134061, 0.4938461538461538, 0.5201581027667984, 0.4936, 0.4895498392282958, 0.4724842767295597, 0.5066147859922179, 0.5221169036334913, 0.49140625, 0.5104408352668214, 0.4833860759493671, 0.5197215777262181, 0.5032, 0.5228706624605678, 0.49206349206349204, 0.5393518518518519, 0.5407114624505929, 0.5235811350919265, 0.48093385214007783, 0.5545171339563862, 0.49923195084485406, 0.5295043273013376, 0.5101404056162246, 0.5453149001536098, 0.5796425796425796, 0.46017014694508895, 0.5019394879751745, 0.49645390070921985, 0.4792806880375293, 0.39257503949447076, 0.4765258215962441]
# [0.6703210649960846, 0.638801261829653, 0.619233776387803, 0.6429136975455265, 0.6529051987767585, 0.6051805337519623, 0.6182096403978576, 0.6270523846755277, 0.6559561128526645, 0.6513833992094862, 0.6090342679127726, 0.6071987480438185, 0.6558028616852146, 0.6474308300395257, 0.6552262090483619, 0.6408450704225352, 0.6643356643356644, 0.6535122336227308, 0.6759474091260634, 0.6206349206349207, 0.6299212598425197, 0.6207710464201416, 0.624313725490196, 0.6338582677165354, 0.6495659037095501, 0.6146076146076146, 0.6184834123222749, 0.7131599684791174, 0.6480891719745223, 0.7013996889580093, 0.627906976744186, 0.6079632465543645, 0.7637917637917638, 0.6990445859872612, 0.7444015444015444]
# [0.6703296703296703, 0.6297169811320755, 0.6444792482380579, 0.6601101494885917, 0.629222309505106, 0.627944760357433, 0.6575449569976545, 0.6397807361002349, 0.6772402854877082, 0.6814229249011857, 0.7157320872274143, 0.6648522550544324, 0.6772151898734177, 0.6658576051779935, 0.6422379826635146, 0.7372947615324472, 0.6921259842519685, 0.6535122336227308, 0.6648089171974523, 0.6957878315132605, 0.690923317683881, 0.6800947867298578, 0.6488372093023256, 0.6553359683794466, 0.6249039200614912, 0.6527886881382561, 0.6760904684975767, 0.5993764614185503, 0.6429118773946361, 0.6335118592195869, 0.6309148264984227, 0.6146718146718146, 0.6268540202966433, 0.6669236700077101, 0.6876475216365067]
# [0.6921259842519685, 0.7138364779874213, 0.717140661029977, 0.7044728434504792, 0.610566037735849, 0.6805664830841857, 0.6917057902973396, 0.6764934057408845, 0.6853415195702226, 0.686289697908598, 0.6992307692307692, 0.7407698350353495, 0.6690363349131122, 0.6362217017954723, 0.7023076923076923, 0.7021110242376857, 0.7575039494470774, 0.6936728395061729, 0.6973788721207307, 0.6606583072100314, 0.6793048973143759, 0.6640502354788069, 0.7089314194577353, 0.6557886557886557, 0.6872074882995319, 0.6830427892234548, 0.6331500392772977, 0.7127158555729984, 0.677992277992278, 0.5861801242236024, 0.6234662576687117, 0.6359300476947536, 0.6764252696456087, 0.8091603053435115, 0.7654618473895582]
# [0.7509850275807722, 0.7074303405572755, 0.6612779060816012, 0.6729559748427673, 0.6856474258970359, 0.6493808049535603, 0.7121799844840963, 0.7197258187357197, 0.6957547169811321, 0.6674509803921569, 0.7230411171450737, 0.6782061369000787, 0.647898493259318, 0.7038461538461539, 0.6464646464646465, 0.6238461538461538, 0.6844166014095536, 0.6624704956726987, 0.663093415007657, 0.6483691328560064, 0.6912, 0.6705516705516705, 0.7183098591549296, 0.6455399061032864, 0.6954156954156954, 0.65527950310559, 0.6424100156494522, 0.6513105639396346, 0.7288537549407115, 0.7013502779984114, 0.6629482071713148, 0.7217321571772254, 0.6578332034294622, 0.662754303599374, 0.6431924882629108]
# [0.6153846153846154, 0.705607476635514, 0.6988505747126437, 0.6755695208169678, 0.6538461538461539, 0.6882307092751364, 0.7113636363636363, 0.6826771653543308, 0.6833463643471462, 0.6635367762128326, 0.7008481110254433, 0.7229571984435798, 0.7384259259259259, 0.7311577311577312, 0.6224489795918368, 0.6658841940532081, 0.7442040185471407, 0.6746894409937888, 0.70625, 0.694488188976378, 0.7533596837944664, 0.6753445635528331, 0.6832151300236406, 0.6832151300236406, 0.6462264150943396, 0.6833731105807478, 0.7093479968578161, 0.7162790697674418, 0.6972332015810276, 0.7551181102362204, 0.6859375, 0.6896551724137931, 0.6920031670625495, 0.6827747466874513, 0.706020328381548]
# [0.6892210857592447, 0.6685170499603489, 0.7515479876160991, 0.7231012658227848, 0.7095761381475667, 0.7103235747303543, 0.745920745920746, 0.7044566067240031, 0.7059736229635376, 0.7027888446215139, 0.6513975155279503, 0.7498045347928068, 0.6983503534956795, 0.7134052388289677, 0.7075098814229249, 0.6988142292490118, 0.7571761055081458, 0.6855151045701007, 0.6507439310884886, 0.6518691588785047, 0.6988416988416989, 0.731764705882353, 0.675654242664552, 0.7083981337480559, 0.653635652853792, 0.6835443037974683, 0.6964006259780907, 0.6115384615384616, 0.6274509803921569, 0.660828025477707, 0.6848772763262074, 0.7089201877934272, 0.6976377952755906, 0.7186761229314421, 0.6892744479495269]
# [0.711969111969112, 0.7188473520249221, 0.6964006259780907, 0.7059282371294852, 0.6554424432263116, 0.7357310398749023, 0.6565183450429352, 0.682753164556962, 0.6928406466512702, 0.6637519872813991, 0.7158642462509865, 0.7208756841282252, 0.7300232738557021, 0.6861022364217252, 0.6561264822134387, 0.7359375, 0.6873015873015873, 0.6751937984496124, 0.6717440974866717, 0.67221801665405, 0.6923664122137405, 0.6744913928012519, 0.6927286942924159, 0.6819923371647509, 0.6630350194552529, 0.6924882629107981, 0.6972624798711755, 0.7062015503875969, 0.7325038880248833, 0.6167192429022083, 0.7124901806755696, 0.6692307692307692, 0.6560762509928515, 0.6724683544303798, 0.7107501933488012]
# [0.7163120567375887, 0.6589327146171694, 0.712156862745098, 0.6687402799377916, 0.63721657544957, 0.6618975903614458, 0.7143987341772152, 0.753577106518283, 0.6435958631662689, 0.6510538641686182, 0.7258687258687259, 0.7252146760343482, 0.7215288611544461, 0.6697819314641744, 0.6907692307692308, 0.6604651162790698, 0.6487341772151899, 0.6985871271585558, 0.6786551993745114, 0.705564142194745, 0.7461180124223602, 0.7393364928909952, 0.7119938884644768, 0.6616954474097331, 0.6802147239263804, 0.6801242236024845, 0.6952160493827161, 0.6202143950995406, 0.6759112519809826, 0.753256704980843, 0.6752738654147105, 0.6558391337973705, 0.7454831107619796, 0.7667924528301887, 0.6684574059861857]
# [0.7308892355694228, 0.7034482758620689, 0.7034428794992176, 0.7575289575289575, 0.65284178187404, 0.7574334898278561, 0.7545963229416467, 0.7374429223744292, 0.6851996867658575, 0.6785998408910103, 0.6822066822066822, 0.6475972540045767, 0.7021919879062736, 0.613548883756736, 0.6930232558139535, 0.6919468334636435, 0.6653543307086615, 0.671583850931677, 0.6984251968503937, 0.675, 0.7634241245136186, 0.7193263833199679, 0.6705426356589147, 0.6535685645549318, 0.6454615981380916, 0.68515625, 0.710955710955711, 0.6991492652745553, 0.7452978056426333, 0.7155172413793104, 0.6998420221169036, 0.6914241960183767, 0.7120377655389457, 0.6835043409629045, 0.7674783974862529]
# [0.7367613200306984, 0.7697160883280757, 0.7034099920697859, 0.6578743211792087, 0.6111111111111112, 0.706605222734255, 0.67425431711146, 0.6479750778816199, 0.6734854445318647, 0.6131558339859045, 0.6643464810518175, 0.6841686555290374, 0.6727707006369427, 0.6965678627145085, 0.6866028708133971, 0.6579352850539292, 0.674175382139984, 0.6700706991358995, 0.7072784810126582, 0.6700547302580141, 0.7202194357366771, 0.8515384615384616, 0.710968775020016, 0.7119815668202765, 0.6630179827990618, 0.6590551181102362, 0.6918744971842317, 0.5668740279937792, 0.6998420221169036, 0.7043478260869566, 0.6669213139801375, 0.6209866875489428, 0.6912114014251781, 0.7138461538461538, 0.6423529411764706]
# [0.6790123456790124, 0.752755905511811, 0.7265563435776202, 0.7048799380325329, 0.6699923254029163, 0.6795180722891566, 0.6707882534775889, 0.7170846394984326, 0.6851996867658575, 0.695447409733124, 0.6705698672911787, 0.6748224151539068, 0.702485966319166, 0.6739811912225705, 0.696551724137931, 0.6586314152410575, 0.678125, 0.6974921630094044, 0.6954858454475898, 0.7211311861743912, 0.6568093385214008, 0.6711891460494812, 0.6684910086004691, 0.6804597701149425, 0.7025171624713958, 0.680365296803653, 0.6877470355731226, 0.5625978090766823, 0.6443579766536965, 0.7167584579071598, 0.7108895705521472, 0.6859375, 0.7044025157232704, 0.6344339622641509, 0.6009353078721746]

# %%
plt.plot(wfb,label='batch')
plt.plot(wf,label='personalized')
plt.plot(wp,label='pooled')
plt.legend()

# %%
case = 'case_two'

# %%
wfbr = get_weekly_averages(fb[case][1])
wfr = get_weekly_averages(fp[case][1])
wpr = get_weekly_averages(t[case][1])

# %%
plt.plot(wfbr,'o',label='batch')
plt.plot(wfr,label='personalized')
plt.plot(wpr,label='pooled')
plt.legend()

# %%
for k,v in test.items():
    print(k)
    print(np.array(v).mean())
# Out:
# 2
# 0.4802317784922969
# 1
# 0.5243529361544701

# %%
test = get_interventions('../../Downloads/pooling_results/personalized/','32',7,'case_two','_skewed_three','coef')

# %%
for k,v in test.items():
    print(k)
    print(np.array(v).mean())
# Out:
# 2
# 0.5073564146716852
# 1
# 0.6984589991320309

# %%
save_all('../../Downloads/pooling_results/batch/','32',7,'_skewed_three','coef','batch_skewed')
# Out:
# 50
# 50
# 50

# %%
plot_all('../../Downloads/pooling_results/personalized/','32',7,'515_longnew','coef')
# Out:
# 100
# 0.7127780384270297
# 100
# 0.6207694632613399
# 100
# 0.688776810783113

# %%
plot_all('../../Downloads/pooling_results/batch/','32',7,'515_longnew','coef')
# Out:
# 100
# 0.8018110319355873
# 100
# 0.6789277780374814
# 100
# 0.6945647119303753

# %%
#0.6335868265518692
plot_all('../../Downloads/pooling_results/batch/','32',7,'_4_24pl','coef')
# Out:
# 50
# 0.732929064687011
# 50
# 0.6057083820222462
# 50
# 0.6660065688118749

# %%
plot_all('../../Downloads/pooling_results/personalized/','32',7,'515','coef')
# Out:
# 100
# 0.696950394504223
# 100
# 0.6337271160683071
# 100
# 0.6784991951569043

# %%
plot_all('../../Downloads/pooling_results/personalized/','32',7,'_skewed_three','coef')
# Out:
# 50
# 0.6963424735064452
# 50
# 0.6333998585619742
# 50
# 0.7012133993424519

# %%
plot_all('../../Downloads/pooling_results/personalized/','32',7,'_4_24pl','coef')
# Out:
# 50
# 0.6965837433205749
# 50
# 0.631863205374986
# 50
# 0.6749407231325585

# %%
#between dowpreloc and tpl, these both seem relatively promising 
#- test dowpreloc with more time

# %%
#tpl
50
0.7472792523252064
50
0.6165454737643887
50
0.6686615053522023

# %%
#dow pre loc
#PERSONALIZED
0.6681673658031947
0.6082975236151614
0.6490472608314646

#tpl
50
0.6668255923293641
50
0.5918083714886276
50
0.641138912248373

# %%
#dow pre loc
#PERSONALIZED
0.6681673658031947
0.6082975236151614
0.6490472608314646

# %%
plot_all('../../Downloads/results_4_18/pooling/','32',7,'difstarts','coef')
# Out:
# 0
# nan
# 0
# nan
# 16
# 0.6693968350643922

# %%
# Out:
# 1.3224999999999998

# %%
plot_all('../../Downloads/results_4_16/results/','32',7,'sigmauagain')
# Out:
# 51
# 0.5731156020381111
# 51
# 0.6721511923910594
# 51
# 0.6936533509668307

# %%
import shutil

# %%
case_one = [f for f in os.listdir('../../Downloads/results_4_16/results') if '.pkl' in f and 'case_three' in f]

# %%
for f in case_one:
    shutil.copyfile('../../Downloads/results_4_16/results/{}'.format(f),'../../Downloads/results_4_16/results/case_three/{}'.format(f))

# %%
fn ='population_size_32_update_days_7_short_static_sim_0_preloc_4_18difstarts.pkl'

# %%
with open('{}{}'.format('../../Downloads/results_4_18/pooling/case_three/',fn),'rb') as f:
    test = pickle.load(f)

# %%
test['pprams'].mus2
# Out:
# {0: array([ 0.00313998,  0.50398227, -0.29648448]),
#  1: array([-0.3169843 ,  0.50398227, -0.29648448]),
#  2: array([-0.18103502,  0.50398227, -0.29648448]),
#  3: array([-0.87684544,  0.50398227, -0.29648448]),
#  4: array([ 1.08445036,  0.50398227, -0.29648448]),
#  5: array([-0.19756194,  0.50398227, -0.29648448]),
#  6: array([ 1.19607202,  0.50398227, -0.29648448]),
#  7: array([ 0.20930111,  0.50398227, -0.29648448]),
#  8: array([-1.04088976,  0.50398227, -0.29648448]),
#  9: array([-1.63917723,  0.50398227, -0.29648448]),
#  10: array([ 0.22251186,  0.50398227, -0.29648448]),
#  11: array([ 1.01361213,  0.50398227, -0.29648448]),
#  12: array([-0.25771278,  0.50398227, -0.29648448]),
#  13: array([ 0.67903713,  0.50398227, -0.29648448]),
#  14: array([ 0.31943812,  0.50398227, -0.29648448]),
#  15: array([-0.96416954,  0.50398227, -0.29648448]),
#  16: array([ 3.69890931,  0.50398227, -0.29648448]),
#  17: array([-1.49370038,  0.50398227, -0.29648448]),
#  18: array([ 0.6253796 ,  0.50398227, -0.29648448]),
#  19: array([-0.24227321,  0.50398227, -0.29648448]),
#  20: array([-0.53508562,  0.50398227, -0.29648448]),
#  21: array([ 1.45159198,  0.50398227, -0.29648448]),
#  22: array([-0.76861981,  0.50398227, -0.29648448]),
#  23: array([-0.17239348,  0.50398227, -0.29648448]),
#  24: array([-0.06976554,  0.50398227, -0.29648448]),
#  25: array([-0.43112687,  0.50398227, -0.29648448]),
#  26: array([ 2.0370575 ,  0.50398227, -0.29648448]),
#  27: array([ 0.80680275,  0.50398227, -0.29648448]),
#  28: array([-1.15830639,  0.50398227, -0.29648448]),
#  29: array([-0.27395118,  0.50398227, -0.29648448]),
#  30: array([ 1.52401905,  0.50398227, -0.29648448]),
#  31: array([-0.87857253,  0.50398227, -0.29648448])}
