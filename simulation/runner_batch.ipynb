# %%
import sim_working
import pickle

# %%
#'case_one',
for g in ['None']:
    for p in [32]:
        t=sim_working.run_many('batch',['case_two','case_three','case_one',],0,50,7,'../distributions_rl4rl/','../../Downloads/pooling_results_testing/','None',time_cond=g,pop_size=p)

# %%
x
# Out:
# {Timestamp('2015-07-27 10:00:00'): {'steps': 4.011934498318215,
#   'add': -0.75,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 2.093839455795715,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 0,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-27 10:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-07-27 13:00:00'): {'steps': 4.983638236438806,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.258067510327934,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 0,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-27 13:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-07-27 15:00:00'): {'steps': 6.46747492340265,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.084211185703397,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 0,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-27 15:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-07-27 17:00:00'): {'steps': 2.9212041991341615,
#   'add': -0.65,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.009465459239063,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 0,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-27 17:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-07-27 19:00:00'): {'steps': 6.253092216741857,
#   'add': 0.04999999999999999,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.237464651606198,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 0,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-27 19:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.04999999999999999,
#   'optimal_action': 1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.04999999999999999},
#  Timestamp('2015-07-28 10:00:00'): {'steps': 7.524488912465047,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.83737357576583,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 1,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-28 10:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.050000000000000044,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 0],
#   'calcr': [1, 0, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -0.050000000000000044},
#  Timestamp('2015-07-28 13:00:00'): {'steps': 4.408656967835851,
#   'add': -0.75,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.619313293342461,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 1,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-28 13:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-07-28 15:00:00'): {'steps': 6.2274446613677945,
#   'add': -0.65,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 2.677071482941999,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 1,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-28 15:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-07-28 17:00:00'): {'steps': 5.5979349942760654,
#   'add': None,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.952068502157791,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 1,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-28 17:00:00'),
#   'avail': False,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 1,
#   'other_reward': -100},
#  Timestamp('2015-07-28 19:00:00'): {'steps': 4.366059243372368,
#   'add': -0.35000000000000003,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 5.474531413981041,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 1,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-28 19:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 1],
#   'calcr': [1, 1, 0, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-07-29 10:00:00'): {'steps': 4.948473445722184,
#   'add': -0.35000000000000003,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.739832289693936,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 2,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-29 10:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 0],
#   'calcr': [1, 0, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-07-29 13:00:00'): {'steps': 4.550802598973475,
#   'add': -0.050000000000000044,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 6.563027265266109,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 2,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-29 13:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.050000000000000044,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 0],
#   'calcr': [1, 0, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -0.050000000000000044},
#  Timestamp('2015-07-29 15:00:00'): {'steps': 4.847878770449922,
#   'add': -0.25,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.8038867253634177,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 2,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-29 15:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-07-29 17:00:00'): {'steps': 3.6602680044487212,
#   'add': None,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.200157973757365,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 2,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-29 17:00:00'),
#   'avail': False,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-07-29 19:00:00'): {'steps': 3.218004798118044,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.560725527217544,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 2,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-29 19:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-07-30 10:00:00'): {'steps': 5.9871230714443815,
#   'add': -0.75,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 3.6033974671049367,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 3,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-30 10:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-07-30 13:00:00'): {'steps': 3.8550068870666574,
#   'add': -0.35000000000000003,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.877156410988283,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 3,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-30 13:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 0],
#   'calcr': [1, 0, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-07-30 15:00:00'): {'steps': 2.8341709084931264,
#   'add': -0.25,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.5278090476991775,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 3,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-30 15:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-07-30 17:00:00'): {'steps': 3.37937382544062,
#   'add': None,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.076434358401121,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 3,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-30 17:00:00'),
#   'avail': False,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-07-30 19:00:00'): {'steps': 7.093732433526658,
#   'add': None,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 5.020843559299754,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 3,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-30 19:00:00'),
#   'avail': False,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 1],
#   'calcr': [1, 1, 0, 1, 1],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-07-31 10:00:00'): {'steps': 4.207277326545837,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.307547791202217,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 4,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-31 10:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-07-31 13:00:00'): {'steps': 5.5347486289257475,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 7.239962329232952,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 4,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-31 13:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.45000000000000007,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 1],
#   'calcr': [1, 0, 0, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.45000000000000007},
#  Timestamp('2015-07-31 15:00:00'): {'steps': 3.5504343011923196,
#   'add': None,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.416678809288715,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 4,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-31 15:00:00'),
#   'avail': False,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-07-31 17:00:00'): {'steps': 5.032056091268054,
#   'add': None,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.839335209297505,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 4,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-31 17:00:00'),
#   'avail': False,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-07-31 19:00:00'): {'steps': 6.256069839337215,
#   'add': 0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 6.6302726263138085,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 4,
#   'decision_time': 1,
#   'time': Timestamp('2015-07-31 19:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.04999999999999999,
#   'optimal_action': 1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.04999999999999999},
#  Timestamp('2015-08-01 10:00:00'): {'steps': 3.6489662975275676,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 5.788722063620467,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 5,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-01 10:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.25000000000000006,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 1, 1, 1],
#   'calcr': [1, 0, 1, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.25000000000000006},
#  Timestamp('2015-08-01 13:00:00'): {'steps': 4.297834726396861,
#   'add': 0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 6.005745728366494,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 5,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-01 13:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.15000000000000002,
#   'optimal_action': 1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 1, 1, 0],
#   'calcr': [1, 0, 1, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.15000000000000002},
#  Timestamp('2015-08-01 15:00:00'): {'steps': 4.233809749470451,
#   'add': None,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.261861716130952,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 5,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-01 15:00:00'),
#   'avail': False,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 0],
#   'calcr': [1, 1, 1, 0, 0],
#   'other_action': 1,
#   'other_reward': -100},
#  Timestamp('2015-08-01 17:00:00'): {'steps': 5.81959785146681,
#   'add': 0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.212736511117931,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 5,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-01 17:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.25,
#   'optimal_action': 1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 1, 1, 0],
#   'calcr': [1, 1, 1, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.25},
#  Timestamp('2015-08-01 19:00:00'): {'steps': 4.689941373821842,
#   'add': 0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.966500589118959,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 5,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-01 19:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.25,
#   'optimal_action': 1,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 1, 1, 0],
#   'calcr': [1, 1, 1, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.25},
#  Timestamp('2015-08-02 10:00:00'): {'steps': 5.151677360488447,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.5098446806985315,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 6,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-02 10:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.55,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 1],
#   'calcr': [1, 0, 1, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.55},
#  Timestamp('2015-08-02 13:00:00'): {'steps': 3.904777464941069,
#   'add': -0.55,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.523385535522264,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 6,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-02 13:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.55,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 1],
#   'calcr': [1, 0, 1, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.55},
#  Timestamp('2015-08-02 15:00:00'): {'steps': 5.520027930200461,
#   'add': -0.15000000000000002,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.96376920962246,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 6,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-02 15:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 1, 1, 1],
#   'calcr': [1, 1, 1, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-08-02 17:00:00'): {'steps': 2.608553741159767,
#   'add': -0.15000000000000002,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 6.740023555675262,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 6,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-02 17:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 1, 1, 1],
#   'calcr': [1, 1, 1, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-08-02 19:00:00'): {'steps': 3.7420979475580705,
#   'add': -0.04999999999999999,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.912360922006765,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 6,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-02 19:00:00'),
#   'avail': True,
#   'prob': 0.5,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.04999999999999999,
#   'optimal_action': 0,
#   'mu2': [0, 0, 0, 0, 0],
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 0],
#   'calcr': [1, 1, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.04999999999999999},
#  Timestamp('2015-08-03 10:00:00'): {'steps': 4.346560675492183,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.995693295274805,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 7,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-03 10:00:00'),
#   'avail': True,
#   'prob': 0.4903647604195425,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.050000000000000044,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 0],
#   'calcr': [1, 0, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -0.050000000000000044},
#  Timestamp('2015-08-03 13:00:00'): {'steps': 1.8875067533312877,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.47335805282831,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 7,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-03 13:00:00'),
#   'avail': True,
#   'prob': 0.5526734983555225,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-08-03 15:00:00'): {'steps': 7.581225901595291,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 3.8521454850163384,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 7,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-03 15:00:00'),
#   'avail': True,
#   'prob': 0.3952830758034708,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-08-03 17:00:00'): {'steps': 6.106493532092617,
#   'add': 0.04999999999999999,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.385182840009966,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 7,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-03 17:00:00'),
#   'avail': True,
#   'prob': 0.3428536706468952,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.04999999999999999,
#   'optimal_action': 1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.04999999999999999},
#  Timestamp('2015-08-03 19:00:00'): {'steps': 2.359732501409826,
#   'add': None,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.337394848167337,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 7,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-03 19:00:00'),
#   'avail': False,
#   'prob': 0.5877182245716404,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-08-04 10:00:00'): {'steps': 6.539212956274033,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.0300308394377256,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 8,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-04 10:00:00'),
#   'avail': True,
#   'prob': 0.4903647604195425,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.050000000000000044,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 0],
#   'calcr': [1, 0, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -0.050000000000000044},
#  Timestamp('2015-08-04 13:00:00'): {'steps': 8.389667916282674,
#   'add': -0.050000000000000044,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.525708053173152,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 8,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-04 13:00:00'),
#   'avail': True,
#   'prob': 0.4903647604195425,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.050000000000000044,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 0],
#   'calcr': [1, 0, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -0.050000000000000044},
#  Timestamp('2015-08-04 15:00:00'): {'steps': 4.69883401313898,
#   'add': 0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 6.165522572021282,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 8,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-04 15:00:00'),
#   'avail': True,
#   'prob': 0.3428536706468952,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.04999999999999999,
#   'optimal_action': 1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.04999999999999999},
#  Timestamp('2015-08-04 17:00:00'): {'steps': 4.379122583181164,
#   'add': 0.04999999999999999,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.261706046399052,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 8,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-04 17:00:00'),
#   'avail': True,
#   'prob': 0.3428536706468952,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.04999999999999999,
#   'optimal_action': 1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.04999999999999999},
#  Timestamp('2015-08-04 19:00:00'): {'steps': 5.498414859031708,
#   'add': None,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.916200672456043,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 8,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-04 19:00:00'),
#   'avail': False,
#   'prob': 0.3428536706468952,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 1,
#   'other_reward': -100},
#  Timestamp('2015-08-05 10:00:00'): {'steps': 3.617735688125827,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 6.21321234893049,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 9,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-05 10:00:00'),
#   'avail': True,
#   'prob': 0.4903647604195425,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.050000000000000044,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 0],
#   'calcr': [1, 0, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -0.050000000000000044},
#  Timestamp('2015-08-05 13:00:00'): {'steps': 3.962642700426704,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.833812332983223,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 9,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-05 13:00:00'),
#   'avail': True,
#   'prob': 0.4903647604195425,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.050000000000000044,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 0],
#   'calcr': [1, 0, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -0.050000000000000044},
#  Timestamp('2015-08-05 15:00:00'): {'steps': 5.2590653372365175,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.358119879051766,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 9,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-05 15:00:00'),
#   'avail': True,
#   'prob': 0.5877182245716404,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-08-05 17:00:00'): {'steps': 5.147799019941478,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 5.2821203526702005,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 9,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-05 17:00:00'),
#   'avail': True,
#   'prob': 0.21212250203554545,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 1],
#   'calcr': [1, 1, 0, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-08-05 19:00:00'): {'steps': 5.158531307900979,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.304628936197735,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 9,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-05 19:00:00'),
#   'avail': True,
#   'prob': 0.3952830758034708,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-08-06 10:00:00'): {'steps': 7.4053011199790175,
#   'add': -0.050000000000000044,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.778892425845337,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 10,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-06 10:00:00'),
#   'avail': True,
#   'prob': 0.4903647604195425,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.050000000000000044,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 0],
#   'calcr': [1, 0, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -0.050000000000000044},
#  Timestamp('2015-08-06 13:00:00'): {'steps': 3.2761544707059613,
#   'add': None,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.693648868558258,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 10,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-06 13:00:00'),
#   'avail': False,
#   'prob': 0.5526734983555225,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-08-06 15:00:00'): {'steps': 6.481668593754522,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.649495408885389,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 10,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-06 15:00:00'),
#   'avail': True,
#   'prob': 0.3952830758034708,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-08-06 17:00:00'): {'steps': 3.368057563502685,
#   'add': -0.25,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.2455273068238615,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 10,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-06 17:00:00'),
#   'avail': True,
#   'prob': 0.5877182245716404,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-08-06 19:00:00'): {'steps': 3.1294949277482287,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.7248657489710117,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 10,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-06 19:00:00'),
#   'avail': True,
#   'prob': 0.5877182245716404,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-08-07 10:00:00'): {'steps': 3.974827944145952,
#   'add': None,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 5.433235762961794,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 11,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-07 10:00:00'),
#   'avail': False,
#   'prob': 0.32282885359940394,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 1],
#   'calcr': [1, 0, 0, 1, 1],
#   'other_action': 1,
#   'other_reward': -100},
#  Timestamp('2015-08-07 13:00:00'): {'steps': 6.382624651953521,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 3.0661041577394506,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 11,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-07 13:00:00'),
#   'avail': True,
#   'prob': 0.5526734983555225,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-08-07 15:00:00'): {'steps': 4.6320521462413575,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 5.716748391289466,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 11,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-07 15:00:00'),
#   'avail': True,
#   'prob': 0.21212250203554545,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 1],
#   'calcr': [1, 1, 0, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-08-07 17:00:00'): {'steps': 4.054178671060869,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.9973111372148344,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 11,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-07 17:00:00'),
#   'avail': True,
#   'prob': 0.5877182245716404,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-08-07 19:00:00'): {'steps': 3.407540692207431,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 0.9206250239751443,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 11,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-07 19:00:00'),
#   'avail': True,
#   'prob': 0.5877182245716404,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-08-08 10:00:00'): {'steps': 3.4791007982091986,
#   'add': -0.15000000000000002,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.68743820084586,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 12,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-08 10:00:00'),
#   'avail': True,
#   'prob': 0.4438000917856342,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 0],
#   'calcr': [1, 0, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-08-08 13:00:00'): {'steps': 5.067757991121698,
#   'add': -0.15000000000000002,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.132463020721956,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 12,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-08 13:00:00'),
#   'avail': True,
#   'prob': 0.4438000917856342,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 0],
#   'calcr': [1, 0, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-08-08 15:00:00'): {'steps': 5.99274266727247,
#   'add': None,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.035650024416134,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 12,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-08 15:00:00'),
#   'avail': False,
#   'prob': 0.16810490571820846,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 1, 1, 0],
#   'calcr': [1, 1, 1, 1, 0],
#   'other_action': 1,
#   'other_reward': -100},
#  Timestamp('2015-08-08 17:00:00'): {'steps': 4.512687220430234,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.652530115543828,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 12,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-08 17:00:00'),
#   'avail': True,
#   'prob': 0.3092888585125422,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.04999999999999999,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 0],
#   'calcr': [1, 1, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.04999999999999999},
#  Timestamp('2015-08-08 19:00:00'): {'steps': 3.7092654311800217,
#   'add': None,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 3.278700954298251,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 12,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-08 19:00:00'),
#   'avail': False,
#   'prob': 0.18808683539539972,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 1],
#   'calcr': [1, 1, 1, 0, 1],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-08-09 10:00:00'): {'steps': 3.8938471531889105,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 1.906489155065501,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 13,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-09 10:00:00'),
#   'avail': True,
#   'prob': 0.4438000917856342,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 0],
#   'calcr': [1, 0, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-08-09 13:00:00'): {'steps': 4.612881030119299,
#   'add': -0.15000000000000002,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 1.16132962898774,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 13,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-09 13:00:00'),
#   'avail': True,
#   'prob': 0.4438000917856342,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 0],
#   'calcr': [1, 0, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-08-09 15:00:00'): {'steps': 4.611643463073272,
#   'add': -0.04999999999999999,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.429280161913091,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 13,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-09 15:00:00'),
#   'avail': True,
#   'prob': 0.3092888585125422,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.04999999999999999,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 0],
#   'calcr': [1, 1, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.04999999999999999},
#  Timestamp('2015-08-09 17:00:00'): {'steps': 4.078578378665373,
#   'add': 0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.8510661678080504,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 13,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-09 17:00:00'),
#   'avail': True,
#   'prob': 0.16810490571820846,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.25,
#   'optimal_action': 1,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 1, 1, 0],
#   'calcr': [1, 1, 1, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.25},
#  Timestamp('2015-08-09 19:00:00'): {'steps': 3.264737479204584,
#   'add': -0.45,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 3.2856500908203694,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 13,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-09 19:00:00'),
#   'avail': True,
#   'prob': 0.18808683539539972,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.45,
#   'optimal_action': 0,
#   'mu2': array([ 0.25608841, -0.16830803, -0.3340135 , -0.26766413, -0.20145163]),
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 1],
#   'calcr': [1, 1, 1, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.45},
#  Timestamp('2015-08-10 10:00:00'): {'steps': 4.014288333057384,
#   'add': -0.75,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.455340618023074,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 14,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-10 10:00:00'),
#   'avail': True,
#   'prob': 0.37246981964787484,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': array([ 0.28576926, -0.21546684, -0.26763348,  0.21738869, -0.37345642]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-08-10 13:00:00'): {'steps': 5.418239707450735,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 3.835905589231881,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 14,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-10 13:00:00'),
#   'avail': True,
#   'prob': 0.37246981964787484,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': array([ 0.28576926, -0.21546684, -0.26763348,  0.21738869, -0.37345642]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-08-10 15:00:00'): {'steps': 2.7561224331722682,
#   'add': -0.35000000000000003,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 5.279339937215366,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 14,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-10 15:00:00'),
#   'avail': True,
#   'prob': 0.3802242992163324,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': array([ 0.28576926, -0.21546684, -0.26763348,  0.21738869, -0.37345642]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 1],
#   'calcr': [1, 1, 0, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-08-10 17:00:00'): {'steps': 3.0884092740205724,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.9930433898761186,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 14,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-10 17:00:00'),
#   'avail': True,
#   'prob': 0.6289732202714675,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': array([ 0.28576926, -0.21546684, -0.26763348,  0.21738869, -0.37345642]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-08-10 19:00:00'): {'steps': 5.928970780739534,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.169532209034234,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 14,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-10 19:00:00'),
#   'avail': True,
#   'prob': 0.1117316035518478,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': array([ 0.28576926, -0.21546684, -0.26763348,  0.21738869, -0.37345642]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-08-11 10:00:00'): {'steps': 2.219082550117073,
#   'add': -0.75,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.688602886838284,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 15,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-11 10:00:00'),
#   'avail': True,
#   'prob': 0.37246981964787484,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': array([ 0.28576926, -0.21546684, -0.26763348,  0.21738869, -0.37345642]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-08-11 13:00:00'): {'steps': 3.7780503594781325,
#   'add': None,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.3267358907639113,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 15,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-11 13:00:00'),
#   'avail': False,
#   'prob': 0.8,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.28576926, -0.21546684, -0.26763348,  0.21738869, -0.37345642]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 0],
#   'calcr': [1, 0, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-08-11 15:00:00'): {'steps': 5.798101286771777,
#   'add': None,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.7351932835370656,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 15,
#   'decision_time': 1,
#   'time': Timestamp('2015-08-11 15:00:00'),
# ...
#   'decision_time': 1,
#   'time': Timestamp('2015-09-10 10:00:00'),
#   'avail': True,
#   'prob': 0.7712135726725794,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 0],
#   'calcr': [1, 0, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-09-10 13:00:00'): {'steps': 5.21512093867043,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.2120024441640767,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 45,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-10 13:00:00'),
#   'avail': True,
#   'prob': 0.7712135726725794,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 0],
#   'calcr': [1, 0, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-09-10 15:00:00'): {'steps': 4.1828187271343165,
#   'add': 0.04999999999999999,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.119701981090631,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 45,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-10 15:00:00'),
#   'avail': True,
#   'prob': 0.8,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.04999999999999999,
#   'optimal_action': 1,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.04999999999999999},
#  Timestamp('2015-09-10 17:00:00'): {'steps': 1.5416298129239903,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.776849453009247,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 45,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-10 17:00:00'),
#   'avail': True,
#   'prob': 0.1,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-09-10 19:00:00'): {'steps': 4.821155118404702,
#   'add': None,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 3.8650073043168742,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 45,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-10 19:00:00'),
#   'avail': False,
#   'prob': 0.1,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-09-11 10:00:00'): {'steps': 6.402005524081667,
#   'add': None,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.2522146975574646,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 46,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-11 10:00:00'),
#   'avail': False,
#   'prob': 0.7712135726725794,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 0],
#   'calcr': [1, 0, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-09-11 13:00:00'): {'steps': 1.7053915040580567,
#   'add': -0.35000000000000003,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.718634183811377,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 46,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-11 13:00:00'),
#   'avail': True,
#   'prob': 0.7712135726725794,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.35000000000000003,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 0],
#   'calcr': [1, 0, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.35000000000000003},
#  Timestamp('2015-09-11 15:00:00'): {'steps': 6.864239825026415,
#   'add': None,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.955221615441269,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 46,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-11 15:00:00'),
#   'avail': False,
#   'prob': 0.8,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-09-11 17:00:00'): {'steps': 4.925209743619611,
#   'add': -0.25,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.0550320526037997,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 46,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-11 17:00:00'),
#   'avail': True,
#   'prob': 0.48035549397367017,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.25,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.25},
#  Timestamp('2015-09-11 19:00:00'): {'steps': 2.8292906948031833,
#   'add': None,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.782670282027649,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 46,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-11 19:00:00'),
#   'avail': False,
#   'prob': 0.48035549397367017,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 0],
#   'calcr': [1, 1, 0, 0, 0],
#   'other_action': 0,
#   'other_reward': -100},
#  Timestamp('2015-09-12 10:00:00'): {'steps': 2.4972946675417256,
#   'add': -0.15000000000000002,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 3.5317900836254363,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 47,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-12 10:00:00'),
#   'avail': True,
#   'prob': 0.700675736844355,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 0],
#   'calcr': [1, 0, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-09-12 13:00:00'): {'steps': 4.787934135442294,
#   'add': 0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.017200369558868,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 47,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-12 13:00:00'),
#   'avail': True,
#   'prob': 0.8,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': 0.15000000000000002,
#   'optimal_action': 1,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 0, 1, 1, 0],
#   'calcr': [1, 0, 1, 1, 0],
#   'other_action': 1,
#   'other_reward': 0.15000000000000002},
#  Timestamp('2015-09-12 15:00:00'): {'steps': 4.620667723162711,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 4.596918985427411,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 47,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-12 15:00:00'),
#   'avail': True,
#   'prob': 0.43175914176536323,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.04999999999999999,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 0],
#   'calcr': [1, 1, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.04999999999999999},
#  Timestamp('2015-09-12 17:00:00'): {'steps': 2.7144944200647787,
#   'add': -0.0,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.1346619381040464,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 47,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-12 17:00:00'),
#   'avail': True,
#   'prob': 0.43175914176536323,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.04999999999999999,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 0],
#   'calcr': [1, 1, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.04999999999999999},
#  Timestamp('2015-09-12 19:00:00'): {'steps': 1.3567281919101506,
#   'add': -0.04999999999999999,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.9187186525183293,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 47,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-12 19:00:00'),
#   'avail': True,
#   'prob': 0.43175914176536323,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.04999999999999999,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 0],
#   'calcr': [1, 1, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.04999999999999999},
#  Timestamp('2015-09-13 10:00:00'): {'steps': 2.0142046371096436,
#   'add': -0.15000000000000002,
#   'action': 1,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 2.8722886984564435,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 48,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-13 10:00:00'),
#   'avail': True,
#   'prob': 0.700675736844355,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 0],
#   'calcr': [1, 0, 1, 0, 0],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-09-13 13:00:00'): {'steps': 3.174020962950423,
#   'add': -0.55,
#   'action': 1,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 2.200618273836956,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 48,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-13 13:00:00'),
#   'avail': True,
#   'prob': 0.1,
#   'dow': 1,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.55,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 0, 1, 0, 1],
#   'calcr': [1, 0, 1, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.55},
#  Timestamp('2015-09-13 15:00:00'): {'steps': 5.152155180363334,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 3.284832104842991,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 48,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-13 15:00:00'),
#   'avail': True,
#   'prob': 0.1,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.45,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 1, 0, 1],
#   'calcr': [1, 1, 1, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.45},
#  Timestamp('2015-09-13 17:00:00'): {'steps': 6.101617495342383,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 6.3098014477332525,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 48,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-13 17:00:00'),
#   'avail': True,
#   'prob': 0.1,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 1, 1, 1],
#   'calcr': [1, 1, 1, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-09-13 19:00:00'): {'steps': 4.439219768178837,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 5.661297457703635,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 48,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-13 19:00:00'),
#   'avail': True,
#   'prob': 0.1,
#   'dow': 1,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.15000000000000002,
#   'optimal_action': 0,
#   'mu2': array([ 0.08475214, -0.08930042, -0.01618345,  0.21208226, -0.43211317]),
#   'gid': 2,
#   'calc': [1, 1, 1, 1, 1],
#   'calcr': [1, 1, 1, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.15000000000000002},
#  Timestamp('2015-09-14 10:00:00'): {'steps': 6.423083904882732,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.284782261865859,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 49,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-14 10:00:00'),
#   'avail': True,
#   'prob': 0.1,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.75,
#   'optimal_action': 0,
#   'mu2': array([ 0.01564695, -0.04272435,  0.02701584,  0.22344896, -0.38551452]),
#   'gid': 2,
#   'calc': [1, 0, 0, 0, 1],
#   'calcr': [1, 0, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.75},
#  Timestamp('2015-09-14 13:00:00'): {'steps': 4.342401877348205,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 6.106310109008719,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 49,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-14 13:00:00'),
#   'avail': True,
#   'prob': 0.10165579720825091,
#   'dow': 0,
#   'tod': 0,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -0.45000000000000007,
#   'optimal_action': 0,
#   'mu2': array([ 0.01564695, -0.04272435,  0.02701584,  0.22344896, -0.38551452]),
#   'gid': 2,
#   'calc': [1, 0, 0, 1, 1],
#   'calcr': [1, 0, 0, 1, 1],
#   'other_action': 0,
#   'other_reward': -0.45000000000000007},
#  Timestamp('2015-09-14 15:00:00'): {'steps': 4.784786822695144,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.441910920018653,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 49,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-14 15:00:00'),
#   'avail': True,
#   'prob': 0.1,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': array([ 0.01564695, -0.04272435,  0.02701584,  0.22344896, -0.38551452]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-09-14 17:00:00'): {'steps': 4.233535960147904,
#   'add': -0.0,
#   'action': 0,
#   'location': 1,
#   'location_1': 1,
#   'ltps': 4.053192507127142,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 49,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-14 17:00:00'),
#   'avail': True,
#   'prob': 0.1,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 0,
#   'optimal_reward': -0.65,
#   'optimal_action': 0,
#   'mu2': array([ 0.01564695, -0.04272435,  0.02701584,  0.22344896, -0.38551452]),
#   'gid': 2,
#   'calc': [1, 1, 0, 0, 1],
#   'calcr': [1, 1, 0, 0, 1],
#   'other_action': 0,
#   'other_reward': -0.65},
#  Timestamp('2015-09-14 19:00:00'): {'steps': 4.903799192783931,
#   'add': None,
#   'action': 0,
#   'location': 0,
#   'location_1': 0,
#   'ltps': 5.90618533276616,
#   'location_2': 0,
#   'location_3': 0,
#   'study_day': 49,
#   'decision_time': 1,
#   'time': Timestamp('2015-09-14 19:00:00'),
#   'avail': False,
#   'prob': 0.8,
#   'dow': 0,
#   'tod': 1,
#   'weather': 1,
#   'pretreatment': 1,
#   'optimal_reward': -100,
#   'optimal_action': -1,
#   'mu2': array([ 0.01564695, -0.04272435,  0.02701584,  0.22344896, -0.38551452]),
#   'gid': 2,
#   'calc': [1, 1, 0, 1, 0],
#   'calcr': [1, 1, 0, 1, 0],
#   'other_action': 0,
#   'other_reward': -100}}

# %%
t[2].mus2[30]
# Out:
# array([ 0.44326567,  0.06514838, -0.06642719,  0.28923481, -0.44981773])

# %%
x = t[0].population[1].history

# %%
y = t[0].population[1].history

# %%
with open('../Downloads/pooling_results_testing/batch/case_one/population_size_32_update_days_7_short_static_sim_0.pkl','rb') as f:
    d = pickle.load(f)
with open('../Downloads/pooling_results_testing/personalized/case_one/population_size_32_update_days_7_short_static_sim_0.pkl','rb') as f:
    dd = pickle.load(f)

# %%
len(d['gparams'].history)
# Out:
# 3

# %%
len(dd['gparams'].history)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-4f18dc11f4c8> in <module>
# ----> 1 len(dd['gparams'].history)
#
# TypeError: object of type 'NoneType' has no len()
